# %% [markdown]
# Based on https://github.com/huggingface/transformers/tree/master/examples/token-classification
#
# Train model with https://github.com/huggingface/transformers/blob/master/examples/token-classification/run_ner.py

# %%
import sys
import numpy as np
import torch
dummy = torch.zeros(1).cuda()
from transformers import *

# %%
def load_data(filename, field_num):
    with open(filename) as f:
        data = []
        line_acc = []
        for token_line in f:
            token_line = token_line.split()
            if len(token_line) == 0 and len(line_acc) > 0:
                data.append(" ".join(line_acc))
                line_acc = []
            else:
                line_acc.append(token_line[field_num])
        if len(line_acc) > 0:
            data.append(" ".join(line_acc))
            line_acc = []
        return data

# %%
test_inputs = load_data("./test.txt", 0)
test_labels = load_data("./test.txt", 1)
label_list = load_data("./labels.txt", 0)[0].split()

# %%
test_inputs[:3]
# Out:
# ['1951 bis 1953 wurde der nördliche Teil als Jugendburg des Kolpingwerkes gebaut .',
#  'Da Muck das Kriegsschreiben nicht überbracht hat , wird er als Retter des Landes ausgezeichnet und soll zum Schatzmeister ernannt werden .',
#  'Mit 1. Jänner 2007 wurde Robert Schörgenhofer , als Nachfolger des ausgeschiedenen Dietmar Drabek , in die Kaderliste der FIFA-Schiedsrichter aufgenommen .']

# %%
test_labels[:3]
# Out:
# ['O O O O O O O O O O B-OTH O O',
#  'O B-PER O O O O O O O O O O O O O O O O O O O O',
#  'O O O O O B-PER I-PER O O O O O B-PER I-PER O O O O O B-ORGpart O O']

# %%
label_list
# Out:
# ['B-LOC',
#  'B-LOCderiv',
#  'B-LOCpart',
#  'B-ORG',
#  'B-ORGderiv',
#  'B-ORGpart',
#  'B-OTH',
#  'B-OTHderiv',
#  'B-OTHpart',
#  'B-PER',
#  'B-PERderiv',
#  'B-PERpart',
#  'I-LOC',
#  'I-LOCderiv',
#  'I-LOCpart',
#  'I-ORG',
#  'I-ORGderiv',
#  'I-ORGpart',
#  'I-OTH',
#  'I-OTHderiv',
#  'I-OTHpart',
#  'I-PER',
#  'I-PERderiv',
#  'I-PERpart',
#  'O']

# %%
def combine_tokens_and_labels(tokens, labels):
    rv = []
    for i in range(len(tokens)):
        sentence = tokens[i].split()
        label_sent = labels[i].split()
        for j in range(len(sentence)):
            if j == 0 and i > 0:
                rv.append("")
            rv.append(sentence[j] + '    ' + label_sent[j])
    return rv

# %%
combine_tokens_and_labels(test_inputs, test_labels)
# Out:
# ['1951    O',
#  'bis    O',
#  '1953    O',
#  'wurde    O',
#  'der    O',
#  'nördliche    O',
#  'Teil    O',
#  'als    O',
#  'Jugendburg    O',
#  'des    O',
#  'Kolpingwerkes    B-OTH',
#  'gebaut    O',
#  '.    O',
#  '',
#  'Da    O',
#  'Muck    B-PER',
#  'das    O',
#  'Kriegsschreiben    O',
#  'nicht    O',
#  'überbracht    O',
#  'hat    O',
#  ',    O',
#  'wird    O',
#  'er    O',
#  'als    O',
#  'Retter    O',
#  'des    O',
#  'Landes    O',
#  'ausgezeichnet    O',
#  'und    O',
#  'soll    O',
#  'zum    O',
#  'Schatzmeister    O',
#  'ernannt    O',
#  'werden    O',
#  '.    O',
#  '',
#  'Mit    O',
#  '1.    O',
#  'Jänner    O',
#  '2007    O',
#  'wurde    O',
#  'Robert    B-PER',
#  'Schörgenhofer    I-PER',
#  ',    O',
#  'als    O',
#  'Nachfolger    O',
#  'des    O',
#  'ausgeschiedenen    O',
#  'Dietmar    B-PER',
#  'Drabek    I-PER',
#  ',    O',
#  'in    O',
#  'die    O',
#  'Kaderliste    O',
#  'der    O',
#  'FIFA-Schiedsrichter    B-ORGpart',
#  'aufgenommen    O',
#  '.    O',
#  '',
#  'Die    O',
#  'These    O',
#  ',    O',
#  'Schlatter    B-PER',
#  'sei    O',
#  'Antisemit    O',
#  'gewesen    O',
#  ',    O',
#  'wurde    O',
#  'seither    O',
#  'in    O',
#  'der    O',
#  'theologischen    O',
#  'Fachliteratur    O',
#  'nicht    O',
#  'mehr    O',
#  'vertreten    O',
#  '.    O',
#  '',
#  '"    O',
#  'Lehmbruck    B-OTH',
#  '-    I-OTH',
#  'Beuys    I-OTH',
#  '.Zeichnungen    I-OTH',
#  '"    O',
#  'lautet    O',
#  'der    O',
#  'Titel    O',
#  'der    O',
#  'gerade    O',
#  'eröffneten    O',
#  'Ausstellung    O',
#  ',    O',
#  'die    O',
#  'Kuratorin    O',
#  'Dr    O',
#  '.    O',
#  'Marion    B-PER',
#  'Bornscheuer    I-PER',
#  'bis    O',
#  'zum    O',
#  '11.    O',
#  'Januar    O',
#  'im    O',
#  'Lehmbruck-Museum    B-ORG',
#  'präsentiert    O',
#  '.    O',
#  '',
#  'Der    O',
#  'Videohoster    O',
#  'und    O',
#  'die    O',
#  'Vertreter    O',
#  'der    O',
#  'Autoren    O',
#  'schieben    O',
#  'sich    O',
#  'gegenseitig    O',
#  'den    O',
#  'schwarzen    O',
#  'Peter    B-PER',
#  'zu    O',
#  '.    O',
#  '',
#  'Die    O',
#  'Kanzel    O',
#  'befindet    O',
#  'sich    O',
#  'an    O',
#  'der    O',
#  'Südseite    O',
#  'des    O',
#  'Saals    O',
#  '.    O',
#  '',
#  'Zuletzt    O',
#  'war    O',
#  'es    O',
#  'Wolfram    B-PER',
#  'Graf-Rudolf    I-PER',
#  ',    O',
#  'Chef    O',
#  'des    O',
#  'Zoos    O',
#  'in    O',
#  'Aachen    B-LOC',
#  '.    O',
#  '',
#  'Nach    O',
#  'den    O',
#  'Symptomen    O',
#  'lassen    O',
#  'sich    O',
#  'die    O',
#  'beiden    O',
#  'Krankheiten    O',
#  '-    O',
#  '"    O',
#  'normale    O',
#  '"    O',
#  'Influenza    O',
#  'und    O',
#  'Schweinegrippe    O',
#  '-    O',
#  'nicht    O',
#  'unterscheiden    O',
#  '.    O',
#  '',
#  'Politisch    O',
#  'interessiert    O',
#  'ging    O',
#  'Antommarchi    B-PER',
#  'nach    O',
#  'Polen    B-LOC',
#  'und    O',
#  'übernahm    O',
#  'dort    O',
#  '1830    O',
#  'während    O',
#  'des    O',
#  'Novemberaufstandes    O',
#  'in    O',
#  'Warschau    B-LOC',
#  'die    O',
#  'Leitung    O',
#  'der    O',
#  'ärztlichen    O',
#  'Anstalten    O',
#  ';    O',
#  'kehrte    O',
#  'jedoch    O',
#  'bald    O',
#  'nach    O',
#  'Paris    B-LOC',
#  'zurück    O',
#  '.    O',
#  '',
#  'Am    O',
#  '20.    O',
#  'Januar    O',
#  '1839    O',
#  'gelang    O',
#  'Manuel    B-PER',
#  'Bulnes    I-PER',
#  'bei    O',
#  'der    O',
#  'Belagerung    O',
#  'von    O',
#  'Yungay    B-LOC',
#  'der    O',
#  'entscheidende    O',
#  'Sieg    O',
#  '.    O',
#  '',
#  'Das    O',
#  'Auto    O',
#  'geriet    O',
#  'ins    O',
#  'Schleudern    O',
#  ',    O',
#  'kam    O',
#  'nach    O',
#  'rechts    O',
#  'von    O',
#  'der    O',
#  'Fahrbahn    O',
#  'ab    O',
#  'und    O',
#  'prallte    O',
#  'gegen    O',
#  'einen    O',
#  'Baum    O',
#  '.    O',
#  '',
#  'Die    O',
#  'Dramaturgie    O',
#  'der    O',
#  'Partie    O',
#  'hielt    O',
#  ',    O',
#  'was    O',
#  'sich    O',
#  'Fußballfans    O',
#  'weltweit    O',
#  'erträumt    O',
#  'hatten    O',
#  '.    O',
#  '',
#  'DEG-Torhüter    B-ORGpart',
#  'Jamie    B-PER',
#  'Storr    I-PER',
#  '(    O',
#  'Mitte    O',
#  ')    O',
#  'kann    O',
#  'den    O',
#  'Schuss    O',
#  'zum    O',
#  '1:0    O',
#  'nicht    O',
#  'parieren    O',
#  '.    O',
#  '',
#  'Im    O',
#  'Bereich    O',
#  'der    O',
#  'strukturierten    O',
#  'Produkte    O',
#  'beobachten    O',
#  'wir    O',
#  'derzeit    O',
#  'sogar    O',
#  'Rekordvolumen    O',
#  '.    O',
#  '',
#  'Die    O',
#  'monatelange    O',
#  'Führungskrise    O',
#  'beim    O',
#  'europäischen    B-LOCderiv',
#  'Luft-und    O',
#  'Raumfahrtkonzern    O',
#  'EADS    B-ORG',
#  'ist    O',
#  'beigelegt    O',
#  '.    O',
#  '',
#  'Denn    O',
#  'das    O',
#  'ist    O',
#  'nicht    O',
#  'in    O',
#  'Ordnung    O',
#  'was    O',
#  'du    O',
#  'heute    O',
#  'hier    O',
#  'gemacht    O',
#  'hast    O',
#  '!    O',
#  '',
#  'Heute    O',
#  'ist    O',
#  'durch    O',
#  'einen    O',
#  'roten    O',
#  'Ziegelstreifen    O',
#  'der    O',
#  'Verlauf    O',
#  'des    O',
#  'an    O',
#  'den    O',
#  'Turm    O',
#  'anschließenden    O',
#  'nordwestlichen    O',
#  'Mauerrings    O',
#  'gekennzeichnet    O',
#  ',    O',
#  'während    O',
#  'der    O',
#  'südwestliche    O',
#  'Mauerring    O',
#  'bis    O',
#  'zum    O',
#  'Gelände    O',
#  'des    O',
#  'ehemaligen    O',
#  'Franziskanerklosters    O',
#  'St    B-LOC',
#  '.    I-LOC',
#  'Johannis    I-LOC',
#  'noch    O',
#  'intakt    O',
#  'ist    O',
#  '.    O',
#  '',
#  'Verwaltungsdienst    O',
#  'Zumeist    O',
#  'im    O',
#  'Hintergrund    O',
#  'handelnd    O',
#  'ist    O',
#  'der    O',
#  'in    O',
#  'allen    O',
#  'Polizeien    O',
#  'tätige    O',
#  'Verwaltungsdienst    O',
#  'selten    O',
#  'in    O',
#  'Uniform    O',
#  'anzutreffen    O',
#  '.    O',
#  '',
#  'Mit    O',
#  'Herzog    O',
#  'Przemysław    B-PER',
#  'II.    I-PER',
#  'von    O',
#  'Großpolen    B-LOC',
#  'schloss    O',
#  'Mestwin    B-PER',
#  'am    O',
#  '15.    O',
#  'Februar    O',
#  '1282    O',
#  'im    O',
#  'Vertrag    O',
#  'von    O',
#  'Kempen    B-LOC',
#  'eine    O',
#  '„    O',
#  'donatio    O',
#  'inter    O',
#  'vivos    O',
#  '“    O',
#  '(    O',
#  'Geschenk    O',
#  'unter    O',
#  'Lebenden    O',
#  ')    O',
#  'und    O',
#  'vermachte    O',
#  'ihm    O',
#  'sein    O',
#  'Herzogtum    O',
#  '.    O',
#  '',
#  'Philosophisch    O',
#  'strittig    O',
#  'ist    O',
#  ',    O',
#  'ob    O',
#  'der    O',
#  'Raum    O',
#  '„    O',
#  'an    O',
#  'sich    O',
#  '“    O',
#  ',    O',
#  'unabhängig    O',
#  'von    O',
#  'Wahrnehmung    O',
#  'und    O',
#  'Vorstellung    O',
#  'existiert    O',
#  'oder    O',
#  'lediglich    O',
#  'eine    O',
#  'Anschauungsform    O',
#  'des    O',
#  'wahrnehmenden    O',
#  'Subjekts    O',
#  'ist    O',
#  '.    O',
#  '',
#  'Die    O',
#  'London    B-ORG',
#  'Telegram    I-ORG',
#  'vom    O',
#  '21.    O',
#  'Januar    O',
#  '1914    O',
#  'berichtete    O',
#  ',    O',
#  'dass    O',
#  'Karl    B-PER',
#  'Richter    I-PER',
#  'wegen    O',
#  'des    O',
#  'Diebstahls    O',
#  'der    O',
#  'belastenden    O',
#  'Papiere    O',
#  'und    O',
#  'der    O',
#  'versuchten    O',
#  'Erpressung    O',
#  'seines    O',
#  'Arbeitgebers    O',
#  ',    O',
#  'in    O',
#  'Deutschland    B-LOC',
#  'zu    O',
#  '2    O',
#  'Jahren    O',
#  'Gefängnis    O',
#  'verurteilt    O',
#  'wurde    O',
#  '.    O',
#  '',
#  'Folge    O',
#  'ausgestrahlt    O',
#  'wird    O',
#  '.    O',
#  '',
#  'Das    O',
#  'älteste    O',
#  ',    O',
#  'das    O',
#  'Schauspielhaus    O',
#  ',    O',
#  'ist    O',
#  'über    O',
#  '130    O',
#  'Jahre    O',
#  'alt    O',
#  '.    O',
#  '',
#  'Die    O',
#  'ursprüngliche    O',
#  'Apfeldiätspeise    O',
#  '„    O',
#  'd    B-OTH',
#  'Spys    I-OTH',
#  '“    O',
#  'Das    O',
#  'ursprüngliche    O',
#  'Birchermues    O',
#  'ist    O',
#  'eine    O',
#  'Schweizer    B-LOCderiv',
#  'Spezialität    O',
#  'und    O',
#  'wurde    O',
#  'um    O',
#  '1900    O',
#  'Albert    B-PER',
#  'Wirz    I-PER',
#  'Doktor    O',
#  'Birchers    B-PER',
#  'neue    O',
#  'Weltordnung    O',
#  '.    O',
#  '',
#  'Der    O',
#  'wichtigste    O',
#  'Industriezweig    O',
#  'ist    O',
#  'die    O',
#  'Nahrungsmittel-    O',
#  'und    O',
#  'Getränkeindustrie    O',
#  ',    O',
#  'gefolgt    O',
#  'von    O',
#  'der    O',
#  'Metall-    O',
#  'und    O',
#  'der    O',
#  'Textilindustrie    O',
#  '.    O',
#  '',
#  'Der    O',
#  'S    B-OTH',
#  '&    I-OTH',
#  'P    I-OTH',
#  '500    I-OTH',
#  'kletterte    O',
#  'daneben    O',
#  'um    O',
#  '0,91    O',
#  'Prozent    O',
#  'und    O',
#  'schloss    O',
#  'bei    O',
#  '927,23    O',
#  'Zählern    O',
#  '.    O',
#  '',
#  'Auch    O',
#  'im    O',
#  'dritten    O',
#  'Spiel    O',
#  'konnte    O',
#  'sich    O',
#  'keine    O',
#  'der    O',
#  'beiden    O',
#  'Mannschaften    O',
#  'absetzen    O',
#  '.    O',
#  '',
#  'Wie    O',
#  'eine    O',
#  'drohende    O',
#  'Melodie    O',
#  'umschwebte    O',
#  'sie    O',
#  'das    O',
#  'Boot    O',
#  ',    O',
#  'kalt    O',
#  'und    O',
#  'gefühllos    O',
#  '.    O',
#  '',
#  'Eigentlich    O',
#  'sollte    O',
#  'das    O',
#  'neue    O',
#  'Betriebssystem    O',
#  'rechtzeitig    O',
#  'zum    O',
#  'Weihnachtsgeschäft    O',
#  'auf    O',
#  'den    O',
#  'Markt    O',
#  'kommen    O',
#  '.    O',
#  '',
#  'Im    O',
#  'Blickpunkt    O',
#  'des    O',
#  'Interesses    O',
#  'steht    O',
#  'vor    O',
#  'allem    O',
#  'die    O',
#  'anschließende    O',
#  'Presseerklärung    O',
#  ',    O',
#  'von    O',
#  'der    O',
#  'sich    O',
#  'Marktteilnehmer    O',
#  'Hinweise    O',
#  'auf    O',
#  'die    O',
#  'amerikanische    B-LOCderiv',
#  'Geldpolitik    O',
#  'im    O',
#  'kommenden    O',
#  'Jahr    O',
#  'erhoffen    O',
#  '.    O',
#  '',
#  'Mit    O',
#  'der    O',
#  'Verpfändung    O',
#  'Stolbergs    B-LOC',
#  'an    O',
#  'Wilhelm    B-PER',
#  'von    I-PER',
#  'Nesselrode    I-PER',
#  'war    O',
#  'die    O',
#  'Auflage    O',
#  'verbunden    O',
#  ',    O',
#  'dass    O',
#  'eine    O',
#  'mögliche    O',
#  'neue    O',
#  'Burg    O',
#  'als    O',
#  'Offenhaus    O',
#  'des    O',
#  'Herzogs    O',
#  'von    B-PER',
#  'Jülich    I-PER',
#  'zu    O',
#  'errichten    O',
#  'sei    O',
#  '.    O',
#  '',
#  'Er    O',
#  'zeichnete    O',
#  'ein    O',
#  'faires    O',
#  'und    O',
#  'interessantes    O',
#  'Bild    O',
#  'von    O',
#  'der    O',
#  'Auftrags-    O',
#  'und    O',
#  'Arbeitslage    O',
#  'des    O',
#  'Mitteldeutschen    B-ORG',
#  'Verlages    I-ORG',
#  ',    O',
#  'der    O',
#  'als    O',
#  'ein    O',
#  'Nachwuchsautoren-Haus    O',
#  'besonders    O',
#  'gefordert    O',
#  'war    O',
#  '.    O',
#  '',
#  'Ein    O',
#  'Stadtsiegel    O',
#  'mit    O',
#  'dem    O',
#  'Wappen    O',
#  'ist    O',
#  'seit    O',
#  '1297    O',
#  'nachweisbar    O',
#  '.    O',
#  '',
#  'Diese    O',
#  'bestehen    O',
#  'i    O',
#  '.    O',
#  'd    O',
#  '.    O',
#  'R    O',
#  '.    O',
#  'aus    O',
#  'einem    O',
#  'Lösemittel    O',
#  'und    O',
#  'einem    O',
#  'Trägerstoff    O',
#  '.    O',
#  '',
#  'Es    O',
#  'sind    O',
#  'weitere    O',
#  'Zunahmen    O',
#  'der    O',
#  'Belastungen    O',
#  'zu    O',
#  'erwarten    O',
#  '.    O',
#  '',
#  'Doma    B-PER',
#  'ist    O',
#  'immer    O',
#  'noch    O',
#  'sehr    O',
#  'aufgewühlt    O',
#  ',    O',
#  'dass    O',
#  'sie    O',
#  'auf    O',
#  'einen    O',
#  'Gauner    O',
#  'hereingefallen    O',
#  'ist    O',
#  '.    O',
#  '',
#  'Mit    O',
#  '922    O',
#  'm    O',
#  'wird    O',
#  'auf    O',
#  'der    O',
#  'Nordostabdachung    O',
#  'des    O',
#  'Belmont    B-LOC',
#  'die    O',
#  'höchste    O',
#  'Erhebung    O',
#  'von    O',
#  'Bretonvillers    B-LOC',
#  'erreicht    O',
#  '.    O',
#  '',
#  'Kameraarbeit    O',
#  'Auch    O',
#  'den    O',
#  'Posten    O',
#  'als    O',
#  'Kameramann    O',
#  'übernahm    O',
#  'Tarantino    B-PER',
#  'selbst    O',
#  '.    O',
#  '',
#  '"    O',
#  'Wir    O',
#  'sind    O',
#  'vom    O',
#  'Ideal    O',
#  'eines    O',
#  'gebührenfreien    O',
#  'Bildungssystems    O',
#  'von    O',
#  'der    O',
#  'Kinderkrippe    O',
#  'bis    O',
#  'zur    O',
#  'Hochschule    O',
#  'weiter    O',
#  'entfernt    O',
#  'denn    O',
#  'je    O',
#  '"    O',
#  ',    O',
#  'so    O',
#  'Hirsch    B-PER',
#  '.    O',
#  '',
#  'Leopold    B-ORG',
#  'Stocker    I-ORG',
#  'Verlag    I-ORG',
#  ',    O',
#  'Graz    B-LOC',
#  ',    O',
#  'Stuttgart    B-LOC',
#  '1994    O',
#  '.    O',
#  'ISBN    O',
#  '3-702-00682-6    O',
#  '*    O',
#  '1999    O',
#  ':    O',
#  'Erinnerungen    B-OTH',
#  'und    I-OTH',
#  'Gedanken    I-OTH',
#  '.    O',
#  '',
#  '1951    O',
#  'fiel    O',
#  'der    O',
#  'Startschuss    O',
#  'für    O',
#  'die    O',
#  'erste    O',
#  'Berlinale    B-ORG',
#  '.    O',
#  '',
#  'Sie    O',
#  'ermuntert    O',
#  'ihn    O',
#  ',    O',
#  'sich    O',
#  'mehr    O',
#  'auf    O',
#  'sein    O',
#  'Gefühl    O',
#  'und    O',
#  'sein    O',
#  'Gewissen    O',
#  'zu    O',
#  'verlassen    O',
#  ',    O',
#  'ohne    O',
#  'zu    O',
#  'wissen    O',
#  ',    O',
#  'dass    O',
#  'Dexter    B-PER',
#  'keines    O',
#  'von    O',
#  'beiden    O',
#  'hat    O',
#  '.    O',
#  '',
#  'Der    O',
#  '1.    B-ORG',
#  'FC    I-ORG',
#  'Kaiserslautern    I-ORG',
#  'empfängt    O',
#  'heute    O',
#  'im    O',
#  'Montagspiel    O',
#  'der    O',
#  '2.    B-ORG',
#  'Fußball-Bundesliga    I-ORG',
#  'den    O',
#  'SC    B-ORG',
#  'Freiburg    I-ORG',
#  '.    O',
#  '',
#  'Die    O',
#  'Stadt    O',
#  'richtete    O',
#  'in    O',
#  'den    O',
#  'Gebäuden    O',
#  'eine    O',
#  'höhere    O',
#  'Knabenschule    O',
#  'ein    O',
#  ',    O',
#  'weshalb    O',
#  'die    O',
#  'Gebäude    O',
#  'im    O',
#  'Volksmund    O',
#  'auch    O',
#  '„    O',
#  'Bubenkloster    B-OTH',
#  '“    O',
#  'genannt    O',
#  'wurde    O',
#  '(    O',
#  'nicht    O',
#  'zu    O',
#  'verwechseln    O',
#  'mit    O',
#  'der    O',
#  'eigentlichen    O',
#  'Klosterschule    O',
#  'im    O',
#  'Stiftsbezirk    O',
#  ')    O',
#  '.    O',
#  '',
#  'Ein    O',
#  'konsistentes    O',
#  'philosophisches    O',
#  'oder    O',
#  'soziologisches    O',
#  'System    O',
#  'hinterließ    O',
#  'er    O',
#  'nicht    O',
#  ',    O',
#  'auch    O',
#  'keine    O',
#  'Schule    O',
#  '.    O',
#  '',
#  '1297    O',
#  'wurde    O',
#  'nach    O',
#  'einem    O',
#  'Brief    O',
#  'im    O',
#  'Diplomatarium    B-OTH',
#  'Norvegicum    I-OTH',
#  'für    O',
#  'dieses    O',
#  'Jahr    O',
#  'der    O',
#  'Erzbischof    O',
#  'Jørund    B-PER',
#  'in    O',
#  'Nidaros    B-LOC',
#  'zum    O',
#  'Jarl    O',
#  'ernannt    O',
#  '.    O',
#  '',
#  'In    O',
#  'manchen    O',
#  'Gebieten    O',
#  ',    O',
#  'zum    O',
#  'Beispiel    O',
#  'in    O',
#  'Dachau    B-LOC',
#  'Süd    O',
#  ',    O',
#  'gibt    O',
#  'es    O',
#  'nur    O',
#  'wenig    O',
#  'Möglichkeiten    O',
#  'Waren    O',
#  'für    O',
#  'den    O',
#  'alltäglichen    O',
#  'Gebrauch    O',
#  'zu    O',
#  'erwerben    O',
#  '.    O',
#  '',
#  'Bei    O',
#  'den    O',
#  'Privaten    O',
#  'Krankenversicherern    O',
#  'ist    O',
#  'die    O',
#  'DKV    B-ORG',
#  'einer    O',
#  'der    O',
#  'Vorreiter    O',
#  'solcher    O',
#  'Zusatzangebote    O',
#  '.    O',
#  '',
#  'Nach    O',
#  'dem    O',
#  'Abitur    O',
#  'besuchte    O',
#  'sie    O',
#  'die    O',
#  'Musicalschule    O',
#  'Vitztum-Durukan    B-ORG',
#  'in    O',
#  'Hannover    B-LOC',
#  'und    O',
#  'ließ    O',
#  'sich    O',
#  'in    O',
#  'den    O',
#  'Fächern    O',
#  'Schauspiel    O',
#  ',    O',
#  'Tanz    O',
#  'und    O',
#  'Gesang    O',
#  'ausbilden    O',
#  ',    O',
#  'außerdem    O',
#  'nahm    O',
#  'sie    O',
#  'privaten    O',
#  'Gesangsunterricht    O',
#  '.    O',
#  '',
#  'Nach    O',
#  'Ansicht    O',
#  'von    O',
#  'Kritikern    O',
#  'lässt    O',
#  'sich    O',
#  'in    O',
#  'diesen    O',
#  'Forderungen    O',
#  'die    O',
#  'Befürwortung    O',
#  'einer    O',
#  'erneuten    O',
#  'Angliederung    O',
#  'des    O',
#  'heute    O',
#  'zum    O',
#  'tschechischen    B-LOCderiv',
#  'Staat    O',
#  'gehörenden    O',
#  'Sudetenlandes    B-LOC',
#  'an    O',
#  'Deutschland    B-LOC',
#  'erkennen    O',
#  '.    O',
#  '',
#  'Der    O',
#  'Liberalismus    O',
#  'samt    O',
#  'dem    O',
#  'kapitalistischen    O',
#  'Wirtschaftssystem    O',
#  'schien    O',
#  ...]

# %%
num_labels = len(label_list)
id2label, label2id = dict(), dict()
for i in range(num_labels):
    id2label[i] = label_list[i]
    label2id[label_list[i]] = i

# %%
label2id
# Out:
# {'B-LOC': 0,
#  'B-LOCderiv': 1,
#  'B-LOCpart': 2,
#  'B-ORG': 3,
#  'B-ORGderiv': 4,
#  'B-ORGpart': 5,
#  'B-OTH': 6,
#  'B-OTHderiv': 7,
#  'B-OTHpart': 8,
#  'B-PER': 9,
#  'B-PERderiv': 10,
#  'B-PERpart': 11,
#  'I-LOC': 12,
#  'I-LOCderiv': 13,
#  'I-LOCpart': 14,
#  'I-ORG': 15,
#  'I-ORGderiv': 16,
#  'I-ORGpart': 17,
#  'I-OTH': 18,
#  'I-OTHderiv': 19,
#  'I-OTHpart': 20,
#  'I-PER': 21,
#  'I-PERderiv': 22,
#  'I-PERpart': 23,
#  'O': 24}

# %%
model_name = 'bert-base-multilingual-cased'
#config = AutoConfig.from_pretrained(model_name)
config = AutoConfig.from_pretrained(model_name, num_labels=num_labels, id2label=id2label, label2id=label2id)
tokenizer = AutoTokenizer.from_pretrained(model_name, config=config)
model = AutoModelForTokenClassification.from_pretrained(model_name, config=config)

# %%
model_name = './germeval-model/'
config = AutoConfig.from_pretrained(model_name)
#config = AutoConfig.from_pretrained(model_name, num_labels=num_labels, id2label=id2label, label2id=label2id)
tokenizer = AutoTokenizer.from_pretrained(model_name, config=config)
model = AutoModelForTokenClassification.from_pretrained(model_name, config=config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-30ab0ba155fe> in <module>
#       3 #config = AutoConfig.from_pretrained(model_name, num_labels=num_labels, id2label=id2label, label2id=label2id)
#       4 tokenizer = AutoTokenizer.from_pretrained(model_name, config=config)
# ----> 5 model = AutoModelForTokenClassification.from_pretrained(model_name, config=config, output_hidden_states=True)
#
# /mnt/meili0/amiceli/pytorch-elli-py3.6/lib/python3.6/site-packages/transformers/modeling_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1141         for config_class, model_class in MODEL_FOR_TOKEN_CLASSIFICATION_MAPPING.items():
#    1142             if isinstance(config, config_class):
# -> 1143                 return model_class.from_pretrained(pretrained_model_name_or_path, *model_args, config=config, **kwargs)
#    1144
#    1145         raise ValueError(
#
# /mnt/meili0/amiceli/pytorch-elli-py3.6/lib/python3.6/site-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     620
#     621         # Instantiate model.
# --> 622         model = cls(config, *model_args, **model_kwargs)
#     623
#     624         if state_dict is None and not from_tf:
#
# TypeError: __init__() got an unexpected keyword argument 'output_hidden_states'

# %%
#tokens = tokenizer.encode("Hallo Welt!", add_special_tokens=True, return_tensors='pt')
tokens = tokenizer.encode("Die Universität Zürich (kurz UZH) ist eine Universität in Zürich, in der Schweiz.", add_special_tokens=True, return_tensors='pt')

# %%
tokens
# Out:
# tensor([[  101, 10236, 13071, 19985,   113, 21375,   158, 13966, 12396,   114,
#          10298, 10359, 13071, 10106, 19985,   117, 10106, 10118, 18804,   119,
#            102]])

# %%
tokens.shape
# Out:
# torch.Size([1, 21])

# %%
tokenizer.decode(tokens[0])
# Out:
# '[CLS] Die Universität Zürich ( kurz UZH ) ist eine Universität in Zürich, in der Schweiz. [SEP]'

# %%
converted_tokens = tokenizer.convert_ids_to_tokens(tokens[0])
converted_tokens
# Out:
# ['[CLS]',
#  'Die',
#  'Universität',
#  'Zürich',
#  '(',
#  'kurz',
#  'U',
#  '##Z',
#  '##H',
#  ')',
#  'ist',
#  'eine',
#  'Universität',
#  'in',
#  'Zürich',
#  ',',
#  'in',
#  'der',
#  'Schweiz',
#  '.',
#  '[SEP]']

# %%
outputs = model(tokens)[0]
#outputs

# %%
outputs
# Out:
# tensor([[[-3.5906e-01, -1.0638e+00, -1.6967e+00,  8.5544e-01, -1.1273e+00,
#           -4.0354e-01, -1.6005e-01, -1.4345e+00, -1.8019e+00, -1.4220e+00,
#           -1.5346e+00, -2.0497e+00, -1.0582e+00, -2.6558e+00, -3.3880e+00,
#            4.6456e-02, -2.3043e+00, -1.2796e+00, -3.4760e-01, -1.8886e+00,
#           -1.9711e+00, -1.2106e+00, -2.4590e+00, -2.2884e+00,  1.0665e+01],
#          [-1.9638e-01, -8.7915e-01, -2.1614e+00,  3.3196e+00, -1.2437e+00,
#           -6.5107e-01,  1.3831e+00, -1.4261e+00, -2.2791e+00, -1.0152e+00,
#           -1.6993e+00, -2.6719e+00, -1.4586e+00, -3.2869e+00, -3.3570e+00,
#            4.5006e-02, -3.0197e+00, -1.7428e+00, -1.6272e-01, -2.1788e+00,
#           -2.3177e+00, -1.1708e+00, -2.8690e+00, -2.5177e+00,  9.3267e+00],
#          [ 2.1120e+00, -8.3915e-01, -1.1120e+00,  8.4668e+00, -9.3635e-01,
#           -3.9917e-01,  1.3020e+00, -1.7527e+00, -2.1602e+00,  3.9323e-01,
#           -1.6782e+00, -1.7720e+00, -1.2818e+00, -2.4580e+00, -2.4322e+00,
#            1.2277e+00, -2.3932e+00, -1.5214e+00, -1.6025e+00, -1.7175e+00,
#           -2.1380e+00, -1.0850e+00, -1.8345e+00, -1.9426e+00,  2.2855e+00],
#          [ 1.8197e+00, -1.8116e+00, -1.4314e+00,  7.0561e-01, -1.2535e+00,
#           -8.1249e-01, -1.5746e+00, -2.1243e+00, -1.9957e+00, -1.9270e+00,
#           -1.8157e+00, -2.1814e+00,  1.6878e+00, -8.0590e-01, -1.8411e+00,
#            8.1746e+00, -1.5124e+00,  4.0587e-01,  6.4748e-01, -9.5268e-01,
#           -2.6874e-01, -2.7152e-02, -1.2234e+00, -1.2843e+00,  1.7498e+00],
#          [-1.1873e+00, -1.2936e+00, -2.1938e+00,  5.4868e-01, -1.0607e+00,
#           -6.0568e-01, -9.7528e-02, -1.1084e+00, -1.9423e+00, -1.9698e+00,
#           -1.4593e+00, -2.2893e+00, -9.3031e-01, -2.4923e+00, -3.0944e+00,
#            6.0470e-01, -2.3397e+00, -1.0679e+00,  8.3002e-01, -1.6513e+00,
#           -1.7027e+00, -8.2838e-01, -2.6449e+00, -2.1516e+00,  1.0448e+01],
#          [-1.1151e+00, -1.1429e+00, -2.4275e+00,  2.3740e+00, -9.3617e-01,
#           -7.4989e-01,  1.3344e+00, -7.5327e-01, -1.8909e+00, -1.4096e+00,
#           -1.5226e+00, -2.4915e+00, -1.4748e+00, -2.8592e+00, -2.9595e+00,
#            3.4970e-03, -2.7822e+00, -1.5879e+00,  1.0217e+00, -1.7485e+00,
#           -2.0843e+00, -1.0656e+00, -2.7182e+00, -2.3998e+00,  8.9838e+00],
#          [ 1.9947e+00, -8.9722e-01, -1.1396e+00,  8.5282e+00, -9.8369e-01,
#           -2.5269e-01,  1.3651e+00, -1.7336e+00, -2.1889e+00,  3.4540e-01,
#           -1.6784e+00, -1.8524e+00, -1.2441e+00, -2.4349e+00, -2.3810e+00,
#            8.8956e-01, -2.4568e+00, -1.6250e+00, -1.6437e+00, -1.7185e+00,
#           -2.2449e+00, -1.0946e+00, -1.8599e+00, -1.9089e+00,  2.4672e+00],
#          [ 1.3428e+00, -1.7925e+00, -1.4665e+00,  3.5120e+00, -1.0749e+00,
#           -9.9303e-02, -1.2853e+00, -2.3128e+00, -2.0379e+00, -1.8309e+00,
#           -1.8011e+00, -2.3595e+00,  6.7120e-01, -1.2607e+00, -2.0561e+00,
#            7.4690e+00, -1.8996e+00, -2.1761e-03, -1.4989e-01, -1.1789e+00,
#           -6.5196e-01, -3.7346e-01, -1.4067e+00, -1.3483e+00,  1.8571e+00],
#          [ 1.5244e+00, -2.0549e+00, -1.6019e+00,  9.7608e-01, -1.1879e+00,
#           -4.9337e-01, -1.7096e+00, -2.1434e+00, -2.1978e+00, -2.1728e+00,
#           -1.9153e+00, -2.1914e+00,  1.8997e+00, -9.3021e-01, -1.7728e+00,
#            7.9341e+00, -1.5347e+00,  4.8557e-01,  6.2001e-01, -9.1018e-01,
#           -1.7898e-01, -3.1546e-01, -1.2737e+00, -1.2134e+00,  2.2808e+00],
#          [-8.9520e-01, -1.2392e+00, -2.0560e+00,  1.8076e-01, -1.2155e+00,
#           -5.6784e-01, -5.2399e-01, -1.4620e+00, -1.9541e+00, -2.0555e+00,
#           -1.6072e+00, -2.2378e+00, -6.8327e-01, -2.2335e+00, -3.1155e+00,
#            6.6555e-01, -2.1421e+00, -1.0857e+00,  5.3194e-01, -1.5718e+00,
#           -1.6504e+00, -8.4173e-01, -2.4655e+00, -2.0932e+00,  1.0715e+01],
#          [-7.3531e-01, -1.0420e+00, -1.8380e+00,  1.2910e-01, -1.1682e+00,
#           -5.3324e-01, -6.7037e-01, -1.4740e+00, -1.8902e+00, -1.9652e+00,
#           -1.6243e+00, -2.1665e+00, -7.2899e-01, -2.3268e+00, -3.3123e+00,
#            2.9487e-01, -2.1617e+00, -1.1730e+00,  1.1582e-01, -1.6789e+00,
#           -1.8627e+00, -9.7320e-01, -2.4991e+00, -2.1766e+00,  1.0962e+01],
#          [-7.8363e-01, -1.0938e+00, -1.8235e+00,  3.8221e-01, -1.1682e+00,
#           -4.6333e-01, -4.9599e-01, -1.5234e+00, -1.8612e+00, -1.8319e+00,
#           -1.5960e+00, -2.1403e+00, -8.8901e-01, -2.5215e+00, -3.4026e+00,
#            2.2368e-01, -2.2945e+00, -1.2390e+00,  4.1377e-02, -1.7957e+00,
#           -1.9066e+00, -1.1541e+00, -2.5062e+00, -2.3271e+00,  1.0982e+01],
#          [-3.7551e-01, -1.3348e+00, -1.7991e+00,  2.4148e+00, -8.4531e-01,
#           -9.3838e-02, -3.6429e-02, -1.8749e+00, -1.9108e+00, -1.3664e+00,
#           -1.6998e+00, -2.1787e+00, -1.3931e+00, -3.0193e+00, -3.6665e+00,
#            3.9019e-01, -2.8096e+00, -1.3867e+00, -7.4359e-01, -2.2649e+00,
#           -2.0508e+00, -1.5337e+00, -2.8152e+00, -2.4858e+00,  1.0095e+01],
#          [-7.2430e-01, -1.2683e+00, -1.8563e+00, -1.5328e-01, -1.3238e+00,
#           -6.5845e-01, -8.0933e-01, -1.6002e+00, -1.8991e+00, -1.9397e+00,
#           -1.4927e+00, -2.0229e+00, -5.9006e-01, -2.3014e+00, -3.1142e+00,
#            3.6109e-01, -2.1584e+00, -1.0095e+00,  6.9062e-02, -1.6682e+00,
#           -1.7101e+00, -7.6494e-01, -2.3533e+00, -2.2067e+00,  1.1014e+01],
#          [ 9.1356e+00, -1.1117e+00,  2.7130e-01,  1.2970e+00, -1.2046e+00,
#           -1.6529e+00, -1.1041e-01, -1.9670e+00, -1.7034e+00,  1.8344e-01,
#           -1.5236e+00, -1.2742e+00, -9.0336e-03, -2.2967e+00, -1.9992e+00,
#            3.3810e-01, -1.9563e+00, -7.4070e-01, -6.6895e-01, -1.6229e+00,
#           -1.5349e+00, -1.0847e+00, -1.6325e+00, -1.9642e+00,  2.3427e+00],
#          [-6.3267e-01, -1.2489e+00, -1.8515e+00, -5.4483e-01, -1.4229e+00,
#           -6.8830e-01, -9.2712e-01, -1.4515e+00, -1.7662e+00, -2.0123e+00,
#           -1.3969e+00, -1.9002e+00, -3.6816e-01, -2.2457e+00, -3.1072e+00,
#            1.2085e-01, -1.9677e+00, -1.0939e+00,  1.4877e-01, -1.5158e+00,
#           -1.5745e+00, -6.0444e-01, -2.2842e+00, -2.2139e+00,  1.1004e+01],
#          [-5.7446e-01, -1.0971e+00, -1.7060e+00, -2.2865e-01, -1.3864e+00,
#           -6.6325e-01, -7.2453e-01, -1.4583e+00, -1.7834e+00, -1.9295e+00,
#           -1.4524e+00, -2.0214e+00, -7.0576e-01, -2.4772e+00, -3.1848e+00,
#           -8.1694e-03, -2.0753e+00, -1.1703e+00,  1.1407e-02, -1.7043e+00,
#           -1.7804e+00, -8.1361e-01, -2.3243e+00, -2.2857e+00,  1.1090e+01],
#          [-4.7184e-01, -1.0651e+00, -1.6865e+00, -1.1321e-01, -1.5322e+00,
#           -6.7566e-01, -4.8787e-01, -1.4574e+00, -1.8222e+00, -1.9506e+00,
#           -1.5466e+00, -2.0567e+00, -6.3740e-01, -2.5502e+00, -3.1768e+00,
#           -2.9076e-02, -2.2000e+00, -1.2227e+00,  3.6502e-02, -1.6873e+00,
#           -1.7611e+00, -8.4933e-01, -2.3788e+00, -2.4023e+00,  1.1063e+01],
#          [ 8.9865e+00, -1.5072e-01,  6.7373e-01,  1.5661e+00, -1.1735e+00,
#           -1.9669e+00,  2.1976e-01, -1.9403e+00, -2.0317e+00,  2.6734e-01,
#           -1.5151e+00, -1.7325e+00, -4.1566e-01, -2.2956e+00, -2.0795e+00,
#           -1.9494e-01, -1.9837e+00, -1.1140e+00, -6.9723e-01, -1.7023e+00,
#           -1.5979e+00, -1.2075e+00, -1.5872e+00, -1.9936e+00,  2.4308e+00],
#          [-5.4378e-01, -1.0738e+00, -1.7401e+00,  1.3923e-01, -1.2205e+00,
#           -5.1542e-01, -5.3401e-01, -1.4146e+00, -1.8180e+00, -1.7188e+00,
#           -1.5165e+00, -1.9820e+00, -9.5862e-01, -2.5986e+00, -3.3392e+00,
#            7.2136e-03, -2.1870e+00, -1.2614e+00, -2.0422e-01, -1.6753e+00,
#           -1.8999e+00, -9.8894e-01, -2.4092e+00, -2.2896e+00,  1.1027e+01],
#          [-2.7795e-01, -1.0078e+00, -1.7276e+00,  5.3544e-01, -1.1399e+00,
#           -5.1075e-01, -2.2551e-01, -1.3885e+00, -1.8532e+00, -1.3932e+00,
#           -1.5225e+00, -2.0211e+00, -1.1708e+00, -2.7429e+00, -3.3852e+00,
#           -1.1348e-01, -2.3060e+00, -1.3949e+00, -4.2001e-01, -1.9247e+00,
#           -2.0055e+00, -1.0672e+00, -2.4646e+00, -2.4163e+00,  1.0779e+01]]],
#        grad_fn=<AddBackward0>)

# %%
outputs.shape
# Out:
# torch.Size([1, 6, 25])

# %%
predictions = torch.argmax(outputs, axis=-1)

# %%
def label_ids_to_labels(ids):
    ids = ids.numpy()
    sent_labels_acc = []
    for j in range(ids.shape[1]):
            sent_labels_acc.append(model.config.id2label[ids[0, j]])
    return sent_labels_acc

# %%
predicted_labels = label_ids_to_labels(predictions)

# %%
combine_tokens_and_labels([" ".join(converted_tokens)],[" ".join(predicted_labels)])
# Out:
# ['[CLS]    O',
#  'Die    O',
#  'Universität    B-ORG',
#  'Zürich    I-ORG',
#  '(    O',
#  'kurz    O',
#  'U    B-ORG',
#  '##Z    I-ORG',
#  '##H    I-ORG',
#  ')    O',
#  'ist    O',
#  'eine    O',
#  'Universität    O',
#  'in    O',
#  'Zürich    B-LOC',
#  ',    O',
#  'in    O',
#  'der    O',
#  'Schweiz    B-LOC',
#  '.    O',
#  '[SEP]    O']

# %%
" ".join(predicted_labels)
# Out:
# 'O O O O O O'

# %%
" ".join(converted_tokens)
# Out:
# '[CLS] Hall ##o Welt ! [SEP]'
